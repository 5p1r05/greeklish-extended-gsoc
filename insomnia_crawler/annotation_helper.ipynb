# %%
## import os
import json

forums = os.listdir("forums_info/forums_sampled")

forum = "forums_info/forums_sampled2/Ψυχαγωγία_sample2.json"


with open(forum, "r") as f:
    data = json.load(f)

for post in data:
    text = post['text'].split(" ")
    for i in range(len(text)):
        print(f'{i}: {text[i]}')
        
    print("########")
# Out:
# 0: to
# 1: ergo
# 2: sinexizei
# 3: meta
# 4: kai
# 5: tous
# 6: dixnei
# 7: megalous
# 8: kai
# 9: sinexizei
# 10: i
# 11: istoria
# 12: theos
# 13: o
# 14: tim
# 15: curry
# 16: sto
# 17: ergo...
# 18: kai
# 19: apo
# 20: ta
# 21: pio
# 22: tromaxtika
# 23: erga
# 24: pou
# 25: exo
# 26: dei
# 27: mipos
# 28: iparxoune
# 29: 2
# 30: dvd
# 31: sto
# 32: magazi?
# ########
# 0: Ela
# 1: nte.
# 2: o
# 3: spooker
# 4: ton
# 5: arpakse
# 6: apo
# 7: ta
# 8: moutra
# 9: kai
# 10: ton
# 11: arxise.
# 12: Mallon
# 13: allos
# 14: prepei
# 15: na
# 16: koitaksei
# 17: to
# 18: IQ
# 19: afou
# 20: alla
# 21: diavazei
# 22: k
# 23: alla
# 24: katalavainei......
# 25: tespa.....
# 26: Epeidi
# 27: exoun
# 28: anoiksei
# 29: 3
# 30: topic
# 31: gia
# 32: to
# 33: matrix
# 34: as
# 35: kleidw8ei
# 36: kanena!
# ########
# 0: EXTRAORDINARY
# 1: WAYS
# 2: -
# 3: CONJURE
# 4: ONE
# ########
# 0: jenifer
# 1: rush
# 2: -
# 3: i
# 4: come
# 5: undone
# ########
# 0: file
# 1: dreaming
# 2: den
# ...
